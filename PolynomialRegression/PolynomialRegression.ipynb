# %% [markdown]
# <h1><center>SVM Classification Tree</center></h1>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

import operator
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
np.random.seed(0)
x = 2 - 3 * np.random.normal(0, 1, 1000)
y = x - 2 * (x ** 2) - 1 * (x ** 3) - 0.5 * (x ** 4) - 0.25 * (x ** 5) + np.random.normal(-500, 500, 1000) + 10000

# %%
plt.scatter(x, y, s=10)

# %%
data = {'axis': [], 'r2 train': [], 'rmse train': [], 'r2 test': [], 'rmse test': []}

# %%
x = x[:, np.newaxis]
y = y[:, np.newaxis]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=0)
model = LinearRegression()
model.fit(x_train, y_train)
y_train_pred = model.predict(x_train)
y_test_pred = model.predict(x_test)
plt.scatter(x_train, y_train, s=10)
plt.plot(x_train, y_train_pred, color='r')
plt.show()

plt.scatter(x_test, y_test, s=10)
plt.plot(x_test, y_test_pred, c='r')
plt.show()

print("R2 Score Train:", end='\t')
print(r2_score(y_train, y_train_pred))

print("Root mean square error Train:", end='\t')
print(np.sqrt(mean_squared_error(y_train, y_train_pred)))

print("R2 Score Test:", end='\t')
print(r2_score(y_test, y_test_pred))

print("Root mean square error Train:", end='\t')
print(np.sqrt(mean_squared_error(y_test, y_test_pred)))

data['axis'].append(1)
data['r2 train'].append(r2_score(y_train, y_train_pred))
data['rmse train'].append(np.sqrt(mean_squared_error(y_train, y_train_pred)))
data['r2 test'].append(r2_score(y_test, y_test_pred))
data['rmse test'].append(np.sqrt(mean_squared_error(y_test, y_test_pred)))
# Out:
# R2 Score Train:	0.29713581809069844
# Root mean square error Train:	3411.6225692383996
# R2 Score Test:	0.3294454188336694
# Root mean square error Train:	3043.800952052313

# %%
polynomial_features = PolynomialFeatures(degree=2)
x_train_poly = polynomial_features.fit_transform(x_train)
x_test_poly = polynomial_features.fit_transform(x_test)
model = LinearRegression()
model.fit(x_train_poly, y_train)
y_train_pred = model.predict(x_train_poly)
y_test_pred = model.predict(x_test_poly)

print("R2 Score Train:", end='\t')
print(r2_score(y_train, y_train_pred))

print("Root mean square error Train:", end='\t')
print(np.sqrt(mean_squared_error(y_train, y_train_pred)))

print("R2 Score Test:", end='\t')
print(r2_score(y_test, y_test_pred))

print("Root mean square error Train:", end='\t')
print(np.sqrt(mean_squared_error(y_test, y_test_pred)))

data['axis'].append(2)
data['r2 train'].append(r2_score(y_train, y_train_pred))
data['rmse train'].append(np.sqrt(mean_squared_error(y_train, y_train_pred)))
data['r2 test'].append(r2_score(y_test, y_test_pred))
data['rmse test'].append(np.sqrt(mean_squared_error(y_test, y_test_pred)))

plt.scatter(x_train, y_train, s=10)
# sort the values of x before line plot
sort_axis = operator.itemgetter(0)
sorted_zip = sorted(zip(x_train,y_train_pred), key=sort_axis)
x_train, y_train_pred = zip(*sorted_zip)
plt.plot(x_train, y_train_pred, color='m')
plt.show()

plt.scatter(x_test, y_test, s=10)
sort_axis = operator.itemgetter(0)
sorted_zip = sorted(zip(x_test, y_test_pred), key=sort_axis)
x_test, y_test_pred = zip(*sorted_zip)
plt.plot(x_test, y_test_pred, color='m')
plt.show()
# Out:
# R2 Score Train:	0.6858895900343246
# Root mean square error Train:	2280.6909409508594
# R2 Score Test:	0.7099183187364084
# Root mean square error Train:	2001.9781514761876

# %%
polynomial_features = PolynomialFeatures(degree=3)
x_train_poly = polynomial_features.fit_transform(x_train)
x_test_poly = polynomial_features.fit_transform(x_test)
model = LinearRegression()
model.fit(x_train_poly, y_train)
y_train_pred = model.predict(x_train_poly)
y_test_pred = model.predict(x_test_poly)

print("R2 Score Train:", end='\t')
print(r2_score(y_train, y_train_pred))

print("Root mean square error Train:", end='\t')
print(np.sqrt(mean_squared_error(y_train, y_train_pred)))

print("R2 Score Test:", end='\t')
print(r2_score(y_test, y_test_pred))

print("Root mean square error Train:", end='\t')
print(np.sqrt(mean_squared_error(y_test, y_test_pred)))

data['axis'].append(3)
data['r2 train'].append(r2_score(y_train, y_train_pred))
data['rmse train'].append(np.sqrt(mean_squared_error(y_train, y_train_pred)))
data['r2 test'].append(r2_score(y_test, y_test_pred))
data['rmse test'].append(np.sqrt(mean_squared_error(y_test, y_test_pred)))

plt.scatter(x_train, y_train, s=10)
# sort the values of x before line plot
sort_axis = operator.itemgetter(0)
sorted_zip = sorted(zip(x_train,y_train_pred), key=sort_axis)
x_train, y_train_pred = zip(*sorted_zip)
plt.plot(x_train, y_train_pred, color='m')
plt.show()

plt.scatter(x_test, y_test, s=10)
sort_axis = operator.itemgetter(0)
sorted_zip = sorted(zip(x_test, y_test_pred), key=sort_axis)
x_test, y_test_pred = zip(*sorted_zip)
plt.plot(x_test, y_test_pred, color='m')
plt.show()
# Out:
# R2 Score Train:	0.00284161429825458
# Root mean square error Train:	4063.566259325578
# R2 Score Test:	-0.0009537294720860512
# Root mean square error Train:	3718.828774070457

# %%
# %%time
for i in range(4, 101):
#     print('Degree: ', i)
#     np.random.seed(0)
#     x = 2 - 3 * np.random.normal(0, 1, 500)
#     y = x - 2 * (x ** 2) + 0.5 * (x ** 3) + np.random.normal(-10, 10, 500)

#     # transforming the data to include another axis
#     x = x[:, np.newaxis]
#     y = y[:, np.newaxis]

#     x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=0)
    polynomial_features= PolynomialFeatures(degree=i)
    x_train_poly = polynomial_features.fit_transform(x_train)
    x_test_poly = polynomial_features.fit_transform(x_test)
    model = LinearRegression()
    model.fit(x_train_poly, y_train)
    y_train_pred = model.predict(x_train_poly)
    y_test_pred = model.predict(x_test_poly)

#     print("R2 Score Train:", end='\t')
#     print(r2_score(y_train, y_train_pred))

#     print("Root mean square error Train:", end='\t')
#     print(np.sqrt(mean_squared_error(y_train, y_train_pred)))

    data['axis'].append(i)
    data['r2 train'].append(r2_score(y_train, y_train_pred))
    data['rmse train'].append(np.sqrt(mean_squared_error(y_train, y_train_pred)))
    data['r2 test'].append(r2_score(y_test, y_test_pred))
    data['rmse test'].append(np.sqrt(mean_squared_error(y_test, y_test_pred)))

#     plt.scatter(x_train, y_train, s=10)
#     # sort the values of x before line plot
#     sort_axis = operator.itemgetter(0)
#     sorted_zip = sorted(zip(x_train,y_train_pred), key=sort_axis)
#     x_train, y_train_pred = zip(*sorted_zip)
#     plt.plot(x_train, y_train_pred, color='m')
#     plt.show()

#     print("R2 Score Test:", end='\t')
#     print(r2_score(y_test, y_test_pred))

#     print("Root mean square error Test:", end='\t')
#     print(np.sqrt(mean_squared_error(y_test, y_test_pred)))

#     plt.scatter(x_test, y_test, s=10)
#     sort_axis = operator.itemgetter(0)
#     sorted_zip = sorted(zip(x_test, y_test_pred), key=sort_axis)
#     x_test, y_test_pred = zip(*sorted_zip)
#     plt.plot(x_test, y_test_pred, color='m')
#     plt.show()
# Out:
# Wall time: 678 ms

# %%
df = pd.DataFrame(data)

# %%
from plotly.subplots import make_subplots
import plotly.graph_objects as go
import plotly.offline as pyo

fig = make_subplots(rows=2, cols=2)

fig.add_trace(
    go.Scatter(x=df['axis'], y=data['r2 train'], name='R2 Train'),
    row=1, col=1
)

fig.add_trace(
    go.Scatter(x=df['axis'], y=data['rmse train'], name = 'RMSE Train'),
    row=1, col=2
)

fig.add_trace(
    go.Scatter(x=df['axis'], y=data['r2 test'], name='R2 Test'),
    row=2, col=1
)

fig.add_trace(
    go.Scatter(x=df['axis'], y=data['rmse test'], name='RMSE Test'),
    row=2, col=2
)

# fig.update_layout(height=600, width=800, title_text="Subplots")
pyo.plot(fig, filename='PolynomialRegression.html')
# Out:
# 'PolynomialRegression.html'

# %% [markdown]
# <h1><center>The End</center></h1>
# <p><center>By <b>Alvyn Abranches</b></center></p>
